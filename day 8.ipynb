# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar chart

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
plt.bar(years,runs)
plt.xlabel("Years")
plt.ylabel("runs")
plt.title("Lifetime run score")
# Out:
# Text(0.5, 1.0, 'Lifetime run score')

# %% [markdown]
# ## Line chart

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]
plt.xlabel("Years")
plt.ylabel("runs")
plt.title("Lifetime run score")
plt.plot(years,runs)

# %% [markdown]
# ## pie chart

# %%
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
 
plt.title("Career Runs of Indian Batsmen")

plt.pie(runs,labels=labels,colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x29229849160>,
#   <matplotlib.patches.Wedge at 0x29229e78cd0>,
#   <matplotlib.patches.Wedge at 0x29229e78f50>,
#   <matplotlib.patches.Wedge at 0x29229e791d0>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])
